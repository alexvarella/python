# %%
def calculate_area(length, width):
    area = length * width
    return area

length = 5
width = 5
rectangle_area = calculate_area(length, width)
print(f"The rectangle area is: {rectangle_area}")
# Out:
#   Cell In[32], line 8
#     print(f"The rectangle area is: {rectangle_area}")
#     ^
# IndentationError: unexpected indent

# %%
# Reset the print function if it was overridden
try:
    del print
except:
    pass
    
# Original function remains the same
def calculate_area(length, width):
    area = length * width
    return area

length = 5
width = 5
rectangle_area = calculate_area(length, width)
print(f"The rectangle area is: {rectangle_area}")  # This should work now
# Out:
# The rectangle area is: 25
